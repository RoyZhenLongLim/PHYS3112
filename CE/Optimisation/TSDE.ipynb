# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import jit

# %%
# Physical Constants
hbar = 1.055e-34      # Js
q = 1.602e-19         # C
m = 9.1e-31           # kg
m_dot = 0.2 * m       # kg  
bohr_radii = 5.29e-11 # m
a = 1e-10             # m

# %%
def VDQD(alpha, x1, x2, x):
    return alpha * min((x - x1) ** 2, (x - x2) ** 2)

def VFT(alpha, F, omega, x1, x2, x, t):
    return alpha * min((x - x1) ** 2, (x - x2) ** 2) + F * x * np.cos(omega * t)

# %%
@jit
def construct_H(U):
    return np.diag(on + U) + np.diag(off, 1) + np.diag(off, -1)

# %%
@jit
def compute_eigenvalue_eigenstates(U):
    H = construct_H(U)
    W, V = np.linalg.eigh(H)
    idx = W.argsort()[::1]
    W = W[idx]
    V = V[:, idx]
    return W, V

# %%
def plot_graph(x, y, xlabel, ylabel, title, axis=None):
    if axis is not None:
        axis.plot(x, y)
        axis.set_xlabel(xlabel)
        axis.set_ylabel(ylabel)
        axis.set_title(title)
    else:
        plt.plot(x, y)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.title(title)

# %%
# Spatial Constants
Np = 700
X = a * np.linspace(-Np / 2, Np / 2, Np) / 1e-9  # nm
dx = (X[1] - X[0]) * 1e-9

t0 = hbar ** 2 / (2 * m_dot * (dx ** 2)) / q
on = 2.0 * t0 * np.ones(Np)
off = -t0 * np.ones(Np - 1)

alpha = 2.1e-5
x1, x2 = 15, -15
F = 0.05e-3

# %%
U = np.array([VDQD(alpha, x1, x2, x) for x in X])
W, V = compute_eigenvalue_eigenstates(U)

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
Psi0 = np.multiply(V[:, 0], V[:, 0])
Psi1 = np.multiply(V[:, 1], V[:, 1])
plot_graph(X, U, 'Distance (nm)', 'Potential Energy (eV)', r'Potential Energy', axes[0])
plot_graph(X, Psi0, 'Distance (nm)', 'Probability', r'$|\psi_0|^2$', axes[1])
plot_graph(X, Psi1, 'Distance (nm)', 'Probability', r'$|\psi_1|^2$', axes[2])
plt.show()

# %%
omega = (W[1] - W[0]) / hbar * q
print(f'Energy Gap is {(W[1] - W[0]).real * 1e3:.2F} meV')
print(f'Frequency of Oscillation is {omega.real / (2 * np.pi):.2E} s')
print(f'Period of Oscillation is {2 * np.pi / omega.real:.2E} Hz')
# Out:
# Energy Gap is 0.70 meV
# Frequency of Oscillation is 1.69E+11 s
# Period of Oscillation is 5.93E-12 Hz

# %%
U = np.array([VFT(alpha, F, omega, x1, x2, x, 0) for x in X])
W, V = compute_eigenvalue_eigenstates(U)

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
Psi0 = np.multiply(V[:, 0], V[:, 0])
Psi1 = np.multiply(V[:, 1], V[:, 1])
plot_graph(X, U, 'Distance (nm)', 'Potential Energy (eV)', r'Potential Energy', axes[0])
plot_graph(X, Psi0, 'Distance (nm)', 'Probability', r'$|\psi_0|^2$', axes[1])
plot_graph(X, Psi1, 'Distance (nm)', 'Probability', r'$|\psi_1|^2$', axes[2])
plt.show()

# %%
# Temporal Constants
Nt = 100
T = np.linspace(0, 2 * np.pi / omega, Nt)         # s (double the period)
dt = T[1] - T[0]                                  # s

# %%
U = np.array([VFT(alpha, F, omega, x1, x2, x, 0) for x in X])
W, V = compute_eigenvalue_eigenstates(U)

psi = np.array(V[:, 0], dtype=np.complex128)
H = construct_H(U).astype(np.complex128)

p0 = np.array([np.abs(psi @ V[:, 0])])
p1 = np.array([np.abs(psi @ V[:, 1])])

print(f'Generation 0')
print(f'\t p0 = {np.abs(psi @ V[:, 0]):.2f}')
print(f'\t p1 = {np.abs(psi @ V[:, 1]):.2f}')

for i in range(1, Nt):
    t = T[i]
    U_new = np.array([VFT(alpha, F, omega, x1, x2, x, t) for x in X])
    H_new = construct_H(U_new).astype(np.complex128)
    
    A = (np.identity(Np) + 1j * dt / (2 * hbar) * H_new * q)
    B = (np.identity(Np) - 1j * dt / (2 * hbar) * H * q) @ psi
    psi_new = np.linalg.solve(A, B)
    
    pr0 = np.abs(psi_new @ V[:, 0]) ** 2
    pr1 = np.abs(psi_new @ V[:, 1]) ** 2
    
    p0 = np.append(p0, pr0) 
    p1 = np.append(p1, pr1) 
    
    print(f'Generation {i}, Total Probability = {np.abs(psi_new @ psi_new) ** 2:.2F}')
    print(f'\t p0 = {pr0:.2f}')
    print(f'\t p1 = {pr1:.2f}')
    
    psi = psi_new
    H = H_new
    
plt.plot(p0)
plt.plot(p1)
# Out:
# Generation 0
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 1, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 2, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 3, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 4, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 5, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 6, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 7, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 8, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 9, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 10, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 11, Total Probability = 1.00
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 12, Total Probability = 0.99
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 13, Total Probability = 0.99
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 14, Total Probability = 0.99
# 	 p0 = 1.00
# 	 p1 = 0.00
# Generation 15, Total Probability = 0.98
# 	 p0 = 0.99
# 	 p1 = 0.00
# Generation 16, Total Probability = 0.98
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 17, Total Probability = 0.97
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 18, Total Probability = 0.96
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 19, Total Probability = 0.95
# 	 p0 = 0.98
# 	 p1 = 0.01
# Generation 20, Total Probability = 0.93
# 	 p0 = 0.98
# 	 p1 = 0.02
# Generation 21, Total Probability = 0.91
# 	 p0 = 0.97
# 	 p1 = 0.03
# Generation 22, Total Probability = 0.89
# 	 p0 = 0.96
# 	 p1 = 0.03
# Generation 23, Total Probability = 0.86
# 	 p0 = 0.95
# 	 p1 = 0.04
# Generation 24, Total Probability = 0.83
# 	 p0 = 0.94
# 	 p1 = 0.05
# Generation 25, Total Probability = 0.79
# 	 p0 = 0.93
# 	 p1 = 0.06
# Generation 26, Total Probability = 0.75
# 	 p0 = 0.91
# 	 p1 = 0.08
# Generation 27, Total Probability = 0.70
# 	 p0 = 0.90
# 	 p1 = 0.09
# Generation 28, Total Probability = 0.64
# 	 p0 = 0.88
# 	 p1 = 0.11
# Generation 29, Total Probability = 0.57
# 	 p0 = 0.85
# 	 p1 = 0.13
# Generation 30, Total Probability = 0.50
# 	 p0 = 0.83
# 	 p1 = 0.16
# Generation 31, Total Probability = 0.43
# 	 p0 = 0.80
# 	 p1 = 0.18
# Generation 32, Total Probability = 0.35
# 	 p0 = 0.77
# 	 p1 = 0.21
# Generation 33, Total Probability = 0.27
# 	 p0 = 0.74
# 	 p1 = 0.24
# Generation 34, Total Probability = 0.20
# 	 p0 = 0.70
# 	 p1 = 0.28
# Generation 35, Total Probability = 0.13
# 	 p0 = 0.66
# 	 p1 = 0.31
# Generation 36, Total Probability = 0.07
# 	 p0 = 0.62
# 	 p1 = 0.35
# Generation 37, Total Probability = 0.03
# 	 p0 = 0.57
# 	 p1 = 0.39
# Generation 38, Total Probability = 0.01
# 	 p0 = 0.53
# 	 p1 = 0.43
# Generation 39, Total Probability = 0.02
# 	 p0 = 0.48
# 	 p1 = 0.47
# Generation 40, Total Probability = 0.05
# 	 p0 = 0.43
# 	 p1 = 0.51
# Generation 41, Total Probability = 0.11
# 	 p0 = 0.39
# 	 p1 = 0.55
# Generation 42, Total Probability = 0.20
# 	 p0 = 0.34
# 	 p1 = 0.59
# Generation 43, Total Probability = 0.31
# 	 p0 = 0.30
# 	 p1 = 0.62
# Generation 44, Total Probability = 0.43
# 	 p0 = 0.26
# 	 p1 = 0.66
# Generation 45, Total Probability = 0.56
# 	 p0 = 0.23
# 	 p1 = 0.69
# Generation 46, Total Probability = 0.68
# 	 p0 = 0.19
# 	 p1 = 0.71
# Generation 47, Total Probability = 0.80
# 	 p0 = 0.17
# 	 p1 = 0.73
# Generation 48, Total Probability = 0.89
# 	 p0 = 0.15
# 	 p1 = 0.75
# Generation 49, Total Probability = 0.96
# 	 p0 = 0.14
# 	 p1 = 0.76
# Generation 50, Total Probability = 0.99
# 	 p0 = 0.13
# 	 p1 = 0.76
# Generation 51, Total Probability = 0.98
# 	 p0 = 0.13
# 	 p1 = 0.76
# Generation 52, Total Probability = 0.93
# 	 p0 = 0.14
# 	 p1 = 0.75
# Generation 53, Total Probability = 0.86
# 	 p0 = 0.16
# 	 p1 = 0.74
# Generation 54, Total Probability = 0.76
# 	 p0 = 0.18
# 	 p1 = 0.73
# Generation 55, Total Probability = 0.64
# 	 p0 = 0.21
# 	 p1 = 0.70
# Generation 56, Total Probability = 0.51
# 	 p0 = 0.24
# 	 p1 = 0.68
# Generation 57, Total Probability = 0.39
# 	 p0 = 0.27
# 	 p1 = 0.65
# Generation 58, Total Probability = 0.28
# 	 p0 = 0.31
# 	 p1 = 0.61
# Generation 59, Total Probability = 0.18
# 	 p0 = 0.36
# 	 p1 = 0.58
# Generation 60, Total Probability = 0.10
# 	 p0 = 0.40
# 	 p1 = 0.54
# Generation 61, Total Probability = 0.05
# 	 p0 = 0.45
# 	 p1 = 0.50
# Generation 62, Total Probability = 0.03
# 	 p0 = 0.49
# 	 p1 = 0.46
# Generation 63, Total Probability = 0.02
# 	 p0 = 0.54
# 	 p1 = 0.43
# Generation 64, Total Probability = 0.04
# 	 p0 = 0.58
# 	 p1 = 0.39
# Generation 65, Total Probability = 0.07
# 	 p0 = 0.62
# 	 p1 = 0.35
# Generation 66, Total Probability = 0.12
# 	 p0 = 0.66
# 	 p1 = 0.31
# Generation 67, Total Probability = 0.18
# 	 p0 = 0.70
# 	 p1 = 0.28
# Generation 68, Total Probability = 0.25
# 	 p0 = 0.73
# 	 p1 = 0.25
# Generation 69, Total Probability = 0.31
# 	 p0 = 0.77
# 	 p1 = 0.22
# Generation 70, Total Probability = 0.38
# 	 p0 = 0.80
# 	 p1 = 0.19
# Generation 71, Total Probability = 0.45
# 	 p0 = 0.82
# 	 p1 = 0.16
# Generation 72, Total Probability = 0.52
# 	 p0 = 0.85
# 	 p1 = 0.14
# Generation 73, Total Probability = 0.58
# 	 p0 = 0.87
# 	 p1 = 0.12
# Generation 74, Total Probability = 0.63
# 	 p0 = 0.89
# 	 p1 = 0.10
# Generation 75, Total Probability = 0.68
# 	 p0 = 0.91
# 	 p1 = 0.08
# Generation 76, Total Probability = 0.73
# 	 p0 = 0.92
# 	 p1 = 0.07
# Generation 77, Total Probability = 0.77
# 	 p0 = 0.93
# 	 p1 = 0.06
# Generation 78, Total Probability = 0.81
# 	 p0 = 0.95
# 	 p1 = 0.05
# Generation 79, Total Probability = 0.85
# 	 p0 = 0.95
# 	 p1 = 0.04
# Generation 80, Total Probability = 0.88
# 	 p0 = 0.96
# 	 p1 = 0.03
# Generation 81, Total Probability = 0.90
# 	 p0 = 0.97
# 	 p1 = 0.03
# Generation 82, Total Probability = 0.92
# 	 p0 = 0.97
# 	 p1 = 0.02
# Generation 83, Total Probability = 0.94
# 	 p0 = 0.98
# 	 p1 = 0.02
# Generation 84, Total Probability = 0.96
# 	 p0 = 0.98
# 	 p1 = 0.01
# Generation 85, Total Probability = 0.97
# 	 p0 = 0.98
# 	 p1 = 0.01
# Generation 86, Total Probability = 0.98
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 87, Total Probability = 0.99
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 88, Total Probability = 1.00
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 89, Total Probability = 1.00
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 90, Total Probability = 1.00
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 91, Total Probability = 0.99
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 92, Total Probability = 0.99
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 93, Total Probability = 0.98
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 94, Total Probability = 0.98
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 95, Total Probability = 0.97
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 96, Total Probability = 0.97
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 97, Total Probability = 0.96
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 98, Total Probability = 0.96
# 	 p0 = 0.99
# 	 p1 = 0.01
# Generation 99, Total Probability = 0.95
# 	 p0 = 0.99
# 	 p1 = 0.01
